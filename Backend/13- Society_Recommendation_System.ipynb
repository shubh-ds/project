# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import joblib

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Create Society-Level profiles

# %%
# Load the data
df = pd.read_csv('Output Files\\stage_5b_property_data.csv')
df.head()
# Out:
#     Possession Status Availability Starts From  Floor No Commercial  \
# 0       Ready to Move              Immediately      20.0          Y
# 1       Ready to Move              Immediately      18.0          N
# 2  Under Construction                   Dec 25       5.0          N
# 3       Ready to Move              Immediately       8.0          Y
# 4       Ready to Move              Immediately      16.0          N
#
#                                Developer  Price (Crores)  \
# 0  Tata Housing Development Company Ltd.           0.630
# 1                  Sai Satyam Developers           0.540
# 2                          Birla Estates           0.900
# 3                      Godrej Properties           0.495
# 4                          Tycoons Group           0.657
#
#                                             Landmark  Covered Area  \
# 0                                        Rajoli naka    763.571943
# 1    This property has reputed scholl ints vicinity.    850.000000
# 2  Shahad is one of the attractive locations to o...   1050.000000
# 3                             Majiwada metro station    561.000000
# 4  Close to tree house school, dmart, kdmc garden...   1067.000000
#
#                       Society  sqft Price (INR)  ...  dist_to_csmt_station_km  \
# 0                Tata Amantra       8250.696031  ...                    45.19
# 1            Sai Satyam Homes       6352.000000  ...                    45.19
# 2                 Birla Vanya       8571.000000  ...                    45.19
# 3              Godrej Nirvaan       8824.000000  ...                    45.19
# 4  Tycoons Solitaire Sapphire       6157.000000  ...                    45.19
#
#   dist_to_nariman_point_km dist_to_andheri_east_comm_km  \
# 0                    47.27                        31.16
# 1                    47.27                        31.16
# 2                    47.27                        31.16
# 3                    47.27                        31.16
# 4                    47.27                        31.16
#
#   dist_to_marine_drive_km  dist_to_navi_mumbai_airport_km  \
# 0                    45.7                           30.01
# 1                    45.7                           30.01
# 2                    45.7                           30.01
# 3                    45.7                           30.01
# 4                    45.7                           30.01
#
#   dist_to_vashi_station_km dist_to_sanjay_gandhi_np_km  \
# 0                    23.31                       27.87
# 1                    23.31                       27.87
# 2                    23.31                       27.87
# 3                    23.31                       27.87
# 4                    23.31                       27.87
#
#   dist_to_phoenix_mall_kurla_km dist_to_kokilaben_hospital_km  \
# 0                          30.9                         33.78
# 1                          30.9                         33.78
# 2                          30.9                         33.78
# 3                          30.9                         33.78
# 4                          30.9                         33.78
#
#    dist_to_dh_ambani_school_km
# 0                        34.33
# 1                        34.33
# 2                        34.33
# 3                        34.33
# 4                        34.33
#
# [5 rows x 135 columns]

# %%
# Create Society location map

location_cols = ['City', 'Area', 'Society']

# Create the map
society_location_map = df[location_cols].dropna().drop_duplicates()

# Save the map to a CSV file for app to use
society_location_map.to_csv('Output Files\\Society_Recommendation_System_Files\\society_location_map.csv', index=False)

# %%
# Keep only essential columns relevant for building the recommendation system
df = df.drop(columns=[
    'Possession Status',
    'Availability Starts From',
    'Floor No',
    'Developer',
    'Landmark',
    'sqft Price (INR)',
    'Locality',
    'Unit of Carpet Area',
    'Furnished Type',
    'Facing',
    'Transaction Type',
    'Type of Property',
    'isPrimeLocationProperty',
    'City',
    'Posted By',
    'Total Floors',
    'Unit of Covered Area',
    'Property Lifespan',
    'geocoded_address',
    'Area',
    'Price_bin',
    'Floor Level'
])

# %%
# Convert boolean/binary columns to numeric format before aggregation
for col in ['Commercial']:
    if col in df.columns:
        # Map positive/negative values to 1/0
        df[col] = df[col].replace({
            'Y': 1, 'Yes': 1,
            'N': 0, 'No': 0
        }).astype(float)

# %%
# Make list of columns that are numeric for aggregation.
columns_to_aggregate = df.select_dtypes(include=np.number).columns.tolist()

# %%
# Group by society name and calculate the mean of all numeric features
society_profiles = df.groupby('Society')[columns_to_aggregate].mean()

# Add a count of listings per society
society_profiles['listing_count'] = df.groupby('Society').size()

# Display
society_profiles.head()
# Out:
#                    Commercial  Price (Crores)  Covered Area  Carpet Area  \
# Society
# 10 Central Avenue    0.000000        4.110000    855.263158   650.000000
# 111 Hyde Park        0.000000        2.800000   1250.000000   700.000000
# 127 Raj Home         0.000000        0.788524    884.588235   567.529412
# 19 North             0.000000        0.950000    632.500000   402.500000
# 25 South             0.368421       16.926395   3140.467315  2201.210526
#
#                    Bathrooms  Bedrooms  Power Back Up  Lift  \
# Society
# 10 Central Avenue   2.000000  2.000000            1.0   1.0
# 111 Hyde Park       2.000000  2.000000            1.0   1.0
# 127 Raj Home        2.000000  1.529412            1.0   1.0
# 19 North            2.000000  1.500000            1.0   1.0
# 25 South            4.263158  3.789474            1.0   1.0
#
#                    Rain Water Harvesting  Club House  ...  \
# Society                                               ...
# 10 Central Avenue                    1.0         1.0  ...
# 111 Hyde Park                        1.0         1.0  ...
# 127 Raj Home                         1.0         1.0  ...
# 19 North                             1.0         1.0  ...
# 25 South                             1.0         1.0  ...
#
#                    dist_to_nariman_point_km  dist_to_andheri_east_comm_km  \
# Society
# 10 Central Avenue                 16.820000                      4.920000
# 111 Hyde Park                     29.120000                      7.920000
# 127 Raj Home                      17.900588                      7.626471
# 19 North                          23.145000                      8.515000
# 25 South                           9.475789                     11.921579
#
#                    dist_to_marine_drive_km  dist_to_navi_mumbai_airport_km  \
# Society
# 10 Central Avenue                14.860000                       24.920000
# 111 Hyde Park                    27.150000                       30.640000
# 127 Raj Home                     16.004706                       21.259412
# 19 North                         21.205000                       27.085000
# 25 South                          7.518421                       22.616842
#
#                    dist_to_vashi_station_km  dist_to_sanjay_gandhi_np_km  \
# Society
# 10 Central Avenue                 17.070000                    17.210000
# 111 Hyde Park                     19.850000                     4.910000
# 127 Raj Home                      13.439412                    18.133529
# 19 North                          18.120000                    11.460000
# 25 South                          18.131579                    24.586316
#
#                    dist_to_phoenix_mall_kurla_km  \
# Society
# 10 Central Avenue                       5.140000
# 111 Hyde Park                          12.170000
# 127 Raj Home                            4.890000
# 19 North                                8.990000
# 25 South                                9.236842
#
#                    dist_to_kokilaben_hospital_km  dist_to_dh_ambani_school_km  \
# Society
# 10 Central Avenue                       4.840000                     3.120000
# 111 Hyde Park                           7.840000                    14.020000
# 127 Raj Home                            9.380588                     3.737059
# 19 North                                8.945000                     8.720000
# 25 South                               12.308421                     6.093684
#
#                    listing_count
# Society
# 10 Central Avenue              1
# 111 Hyde Park                  1
# 127 Raj Home                  17
# 19 North                       2
# 25 South                      19
#
# [5 rows x 112 columns]

# %%
# Dump the society_profiles for app to use
joblib.dump(society_profiles, 'Output Files\\Society_Recommendation_System_Files\\society_profiles.joblib')
# Out:
# ['Output Files\\Society_Recommendation_System_Files\\society_profiles.joblib']

# %% [markdown]
# Scale the society_profiles ensuring all features have equal weight in the recommendation engine:

# %%
features_to_scale = society_profiles.drop(columns=['listing_count'])  # Exclude Listing Count as it is metadata

# %%
# Initialize the scaler
scaler = StandardScaler()

# Fit the scaler to the data
scaler = scaler.fit(features_to_scale)

# Save the scaler for recommendation on the app
joblib.dump(scaler, 'Output Files\\Society_Recommendation_System_Files\\standardScaler.joblib')

# Transform the data
scaled_features = scaler.transform(features_to_scale)

# %%
# Make dataframe
society_profiles_scaled = pd.DataFrame(scaled_features, columns=features_to_scale.columns, index=features_to_scale.index)

# Dump for app to use
joblib.dump(society_profiles_scaled, 'Output Files\\Society_Recommendation_System_Files\\society_profiles_scaled.joblib')
# Out:
# ['Output Files\\Society_Recommendation_System_Files\\society_profiles_scaled.joblib']
